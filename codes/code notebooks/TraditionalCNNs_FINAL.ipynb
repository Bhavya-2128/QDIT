# %% [markdown]
#  In CIFAR-10, there are 60000, 32x32 color images belonging to 10 classes, with 6000 images from each class. The training dataset contains 50,000 training images and the test dataset contains 10,000 test images.
# <br><br>
# The dataset images are of color images with a (32 x 32) resolution. All the images in the dataset are of shape (32,32,3) where 3 represents the number of channels i.e R-G-B (Red,Green & Blue).

# %% [markdown]
# ## Importing Libraries

# %%
pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (11.0.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.1->visualkeras) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.1->visualkeras) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.1->visualkeras) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.1->visualkeras) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.1->visualkeras) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.1->visualkeras) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.1->visualkeras) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Downloading visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Downloading aggdraw-1.3.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 28.0 MB/s eta 0:00:0000:01
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score

import visualkeras
from PIL import ImageFont

import warnings
warnings.filterwarnings('ignore')

print("Tensorflow version:",tf.__version__)
print("Keras version:",keras.__version__)
# Out:
# Tensorflow version: 2.17.1
# Keras version: 3.5.0

# %% [markdown]
# ## Importing & Reading the dataset

# %% [markdown]
#  The Keras dataset module already comes with the CIFAR-10 dataset. So,we can directly import it using the ‘keras.datasets’ command.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# Importing the CIFAR-10 dataset from Keras
from tensorflow.keras.datasets import cifar10
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
print('X_train Shape: {}'.format(X_train.shape))
print('X_test Shape: {}'.format(X_test.shape))
print('Y_train Shape: {}'.format(Y_train.shape))
print('Y_test Shape: {}'.format(Y_test.shape))
# Out:
# X_train Shape: (50000, 32, 32, 3)
# X_test Shape: (10000, 32, 32, 3)
# Y_train Shape: (50000, 1)
# Y_test Shape: (10000, 1)

# %%
plt.figure()
plt.imshow(X_train[16040])
plt.colorbar()

# %% [markdown]
# ## Normalizing and One-Hot Encoding

# %% [markdown]
#  We have to normalize the data in order to reduce the pixel values. Currently, all the image pixels are in a range from 0–255, and we want the values in the range of 0 and 1. So we can either divide all the pixel values by 255.0 or use the ‘normalize’ command from keras library. As CIFAR-10 has 10 classes, we are using the ‘to_categorical()’ method to one-hot encode the data.

# %%
# Normalizing
X_train = X_train/255
X_test = X_test/255

# One-Hot-Encoding
Y_train_en = to_categorical(Y_train,10)
Y_test_en = to_categorical(Y_test,10)

# %%
# Visualizing the data
for i in range(1,20):
  plt.subplot(2, 10, i)
  plt.imshow(X_train[i])

# %% [markdown]
# ## Building Base Model

# %% [markdown]
# Basic CNN model for getting idea of performance

# %%
    # Base Model
model = Sequential()
model.add(Conv2D(32,(4,4),input_shape = (32,32,3),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(32,(4,4),input_shape = (32,32,3),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(128, activation ='relu'))
model.add(Dense(10, activation ='softmax'))
model.compile(loss ='categorical_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.summary()
history = model.fit(X_train, Y_train_en, epochs = 30, verbose=1,validation_data=(X_test,Y_test_en))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 29, 29, 32)          │           1,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 32)          │          16,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 800)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         102,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 121,802 (475.79 KB)
#  Trainable params: 121,802 (475.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.3780 - loss: 1.7147 - val_accuracy: 0.5088 - val_loss: 1.3471
# Epoch 2/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5520 - loss: 1.2631 - val_accuracy: 0.5742 - val_loss: 1.1977
# Epoch 3/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6130 - loss: 1.1023 - val_accuracy: 0.6231 - val_loss: 1.0777
# Epoch 4/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6509 - loss: 0.9931 - val_accuracy: 0.6275 - val_loss: 1.0674
# Epoch 5/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6749 - loss: 0.9280 - val_accuracy: 0.6398 - val_loss: 1.0272
# Epoch 6/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6951 - loss: 0.8720 - val_accuracy: 0.6629 - val_loss: 0.9769
# Epoch 7/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7187 - loss: 0.8069 - val_accuracy: 0.6568 - val_loss: 0.9945
# Epoch 8/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7335 - loss: 0.7685 - val_accuracy: 0.6694 - val_loss: 0.9649
# Epoch 9/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7424 - loss: 0.7309 - val_accuracy: 0.6699 - val_loss: 0.9781
# Epoch 10/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7584 - loss: 0.6888 - val_accuracy: 0.6764 - val_loss: 0.9890
# Epoch 11/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7672 - loss: 0.6550 - val_accuracy: 0.6755 - val_loss: 1.0023
# Epoch 12/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7829 - loss: 0.6169 - val_accuracy: 0.6692 - val_loss: 1.0260
# Epoch 13/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7910 - loss: 0.5876 - val_accuracy: 0.6732 - val_loss: 1.0190
# Epoch 14/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8022 - loss: 0.5606 - val_accuracy: 0.6596 - val_loss: 1.0815
# Epoch 15/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8110 - loss: 0.5336 - val_accuracy: 0.6718 - val_loss: 1.0885
# Epoch 16/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8225 - loss: 0.5049 - val_accuracy: 0.6657 - val_loss: 1.1327
# Epoch 17/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8287 - loss: 0.4803 - val_accuracy: 0.6667 - val_loss: 1.1534
# Epoch 18/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8362 - loss: 0.4594 - val_accuracy: 0.6695 - val_loss: 1.1842
# Epoch 19/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8454 - loss: 0.4354 - val_accuracy: 0.6621 - val_loss: 1.1800
# Epoch 20/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8513 - loss: 0.4136 - val_accuracy: 0.6541 - val_loss: 1.2738
# Epoch 21/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8603 - loss: 0.3905 - val_accuracy: 0.6595 - val_loss: 1.2820
# Epoch 22/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8689 - loss: 0.3647 - val_accuracy: 0.6543 - val_loss: 1.3656
# Epoch 23/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8758 - loss: 0.3472 - val_accuracy: 0.6625 - val_loss: 1.3830
# Epoch 24/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8844 - loss: 0.3261 - val_accuracy: 0.6531 - val_loss: 1.4382
# Epoch 25/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8871 - loss: 0.3120 - val_accuracy: 0.6617 - val_loss: 1.4701
# Epoch 26/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8976 - loss: 0.2885 - val_accuracy: 0.6548 - val_loss: 1.5352
# Epoch 27/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8914 - loss: 0.2964 - val_accuracy: 0.6539 - val_loss: 1.6210
# Epoch 28/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9043 - loss: 0.2653 - val_accuracy: 0.6550 - val_loss: 1.6509
# Epoch 29/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9090 - loss: 0.2522 - val_accuracy: 0.6549 - val_loss: 1.7297
# Epoch 30/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9122 - loss: 0.2436 - val_accuracy: 0.6496 - val_loss: 1.7424

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='cnn_plot.png', show_shapes=True, show_layer_names=True)

# %%
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=303x221>

# %%
evaluation = model.evaluate(X_test, Y_test_en)
print('Test Accuracy of Base Model: {}'.format(evaluation[1]))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6451 - loss: 1.7631
# Test Accuracy of Base Model: 0.6496000289916992

# %%
def plotloss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.plot(history.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()
plotloss(history)

# %% [markdown]
#  After running our base model with 30 Epochs, we are getting ~91% training accuracy and ~64% test accuracy which is good but as we can see the validation loss is continuously increasing from the first epoch till the last epoch i.e our base model is overfitting.
# <br><br>
# We can achieve this by adding a few dropout layers in our model. Now we are building our model by dropping 25% of units.

# %% [markdown]
# ## Model 1 with Dropout

# %%
# Model_1 with Dropouts
model_1 = Sequential()
model_1.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_1.add(MaxPooling2D(pool_size=(2,2)))
model_1.add(Dropout(0.5))
model_1.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_1.add(MaxPooling2D(pool_size=(2,2)))
model_1.add(Dropout(0.25))
model_1.add(Flatten())
model_1.add(Dense(256,activation='relu'))
model_1.add(Dense(10,activation='softmax'))
model_1.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_1.summary()
history_1 = model_1.fit(X_train, Y_train_en, epochs = 50, verbose=1, validation_data=(X_test,Y_test_en))
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 29, 29, 64)          │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 11, 11, 64)          │          65,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         409,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 481,162 (1.84 MB)
#  Trainable params: 481,162 (1.84 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.3459 - loss: 1.7760 - val_accuracy: 0.5421 - val_loss: 1.2981
# Epoch 2/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5417 - loss: 1.2883 - val_accuracy: 0.5713 - val_loss: 1.2051
# Epoch 3/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5879 - loss: 1.1547 - val_accuracy: 0.6328 - val_loss: 1.0636
# Epoch 4/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6272 - loss: 1.0482 - val_accuracy: 0.6456 - val_loss: 1.0297
# Epoch 5/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6514 - loss: 0.9864 - val_accuracy: 0.6689 - val_loss: 0.9705
# Epoch 6/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6817 - loss: 0.9004 - val_accuracy: 0.6888 - val_loss: 0.9171
# Epoch 7/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6946 - loss: 0.8665 - val_accuracy: 0.6891 - val_loss: 0.9015
# Epoch 8/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7178 - loss: 0.8111 - val_accuracy: 0.6927 - val_loss: 0.8972
# Epoch 9/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7256 - loss: 0.7822 - val_accuracy: 0.6962 - val_loss: 0.8822
# Epoch 10/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7335 - loss: 0.7517 - val_accuracy: 0.7046 - val_loss: 0.8736
# Epoch 11/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7478 - loss: 0.7134 - val_accuracy: 0.6901 - val_loss: 0.9097
# Epoch 12/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7596 - loss: 0.6830 - val_accuracy: 0.7119 - val_loss: 0.8680
# Epoch 13/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7682 - loss: 0.6533 - val_accuracy: 0.7009 - val_loss: 0.9013
# Epoch 14/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7792 - loss: 0.6296 - val_accuracy: 0.7027 - val_loss: 0.8930
# Epoch 15/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7802 - loss: 0.6232 - val_accuracy: 0.6976 - val_loss: 0.9215
# Epoch 16/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7888 - loss: 0.5994 - val_accuracy: 0.7086 - val_loss: 0.8908
# Epoch 17/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7949 - loss: 0.5782 - val_accuracy: 0.7052 - val_loss: 0.9015
# Epoch 18/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8039 - loss: 0.5540 - val_accuracy: 0.6962 - val_loss: 0.9327
# Epoch 19/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8062 - loss: 0.5496 - val_accuracy: 0.7106 - val_loss: 0.9108
# Epoch 20/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8056 - loss: 0.5502 - val_accuracy: 0.7003 - val_loss: 0.9703
# Epoch 21/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8125 - loss: 0.5336 - val_accuracy: 0.7156 - val_loss: 0.9203
# Epoch 22/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8145 - loss: 0.5291 - val_accuracy: 0.7104 - val_loss: 0.9412
# Epoch 23/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8248 - loss: 0.4993 - val_accuracy: 0.7082 - val_loss: 0.9514
# Epoch 24/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8306 - loss: 0.4872 - val_accuracy: 0.7197 - val_loss: 0.9273
# Epoch 25/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8313 - loss: 0.4752 - val_accuracy: 0.7081 - val_loss: 0.9929
# Epoch 26/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8340 - loss: 0.4765 - val_accuracy: 0.7145 - val_loss: 0.9606
# Epoch 27/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8334 - loss: 0.4745 - val_accuracy: 0.7144 - val_loss: 0.9565
# Epoch 28/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8413 - loss: 0.4526 - val_accuracy: 0.7024 - val_loss: 1.0044
# Epoch 29/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8430 - loss: 0.4486 - val_accuracy: 0.7146 - val_loss: 0.9784
# Epoch 30/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8446 - loss: 0.4394 - val_accuracy: 0.7112 - val_loss: 0.9956
# Epoch 31/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8476 - loss: 0.4332 - val_accuracy: 0.7064 - val_loss: 0.9854
# Epoch 32/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8469 - loss: 0.4275 - val_accuracy: 0.7018 - val_loss: 1.0412
# Epoch 33/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8511 - loss: 0.4277 - val_accuracy: 0.7059 - val_loss: 0.9946
# Epoch 34/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8525 - loss: 0.4196 - val_accuracy: 0.7139 - val_loss: 1.0044
# Epoch 35/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8530 - loss: 0.4160 - val_accuracy: 0.7155 - val_loss: 1.0190
# Epoch 36/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8596 - loss: 0.4062 - val_accuracy: 0.7096 - val_loss: 1.0191
# Epoch 37/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8602 - loss: 0.4004 - val_accuracy: 0.7115 - val_loss: 1.0239
# Epoch 38/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8588 - loss: 0.4084 - val_accuracy: 0.7156 - val_loss: 1.0334
# Epoch 39/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8624 - loss: 0.3951 - val_accuracy: 0.7126 - val_loss: 1.0329
# Epoch 40/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8648 - loss: 0.3946 - val_accuracy: 0.7057 - val_loss: 1.0736
# Epoch 41/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8678 - loss: 0.3817 - val_accuracy: 0.7098 - val_loss: 1.0758
# Epoch 42/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8726 - loss: 0.3731 - val_accuracy: 0.7102 - val_loss: 1.0784
# Epoch 43/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8673 - loss: 0.3784 - val_accuracy: 0.7048 - val_loss: 1.0916
# Epoch 44/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8654 - loss: 0.3832 - val_accuracy: 0.7106 - val_loss: 1.1012
# Epoch 45/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8684 - loss: 0.3795 - val_accuracy: 0.7079 - val_loss: 1.1267
# Epoch 46/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8714 - loss: 0.3719 - val_accuracy: 0.7079 - val_loss: 1.0748
# Epoch 47/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8742 - loss: 0.3665 - val_accuracy: 0.7147 - val_loss: 1.0668
# Epoch 48/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8760 - loss: 0.3632 - val_accuracy: 0.7112 - val_loss: 1.0741
# Epoch 49/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8737 - loss: 0.3619 - val_accuracy: 0.7109 - val_loss: 1.0829
# Epoch 50/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8761 - loss: 0.3591 - val_accuracy: 0.7106 - val_loss: 1.0925

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_1, to_file='cnn_plot.png', show_shapes=True, show_layer_names=True)

# %%
visualkeras.layered_view(model_1, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=449x221>

# %%
evaluation = model_1.evaluate(X_test, Y_test_en)
print('Test Accuracy of Model_1(with Dropouts): {}'.format(evaluation[1]))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7119 - loss: 1.1001
# Test Accuracy of Model_1(with Dropouts): 0.7106000185012817

# %%
def plotloss(history_1):
    plt.plot(history_1.history['loss'])
    plt.plot(history_1.history['val_loss'])
    plt.plot(history_1.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()
plotloss(history_1)

# %% [markdown]
#  After running our model_1 with 50 Epochs, we can see that the validation accuracy has improved to 71% due to reduction in our model’s validation loss from 1.79 to 1.09.
# <br><br>
# We will continue to train our model by increasing the number of epochs and by adding more filters.

# %% [markdown]
# ## Model 2 with more Filters for better results

# %%
# Model_2 with more filters
model_2 = Sequential()
model_2.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2)))
model_2.add(Dropout(0.4))
model_2.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2)))
model_2.add(Dropout(0.4))
model_2.add(Flatten())
model_2.add(Dense(1024,activation='relu'))
model_2.add(Dense(1024,activation='relu'))
model_2.add(Dense(units =10  , activation = 'softmax'))
model_2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_2.summary()
history_2 = model_2.fit(X_train, Y_train_en, epochs = 100, verbose=1, validation_data=(X_test,Y_test_en))
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 29, 29, 64)          │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 26, 26, 64)          │          65,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 10, 10, 128)         │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 7, 7, 128)           │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │       1,180,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 10)                  │          10,250 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,702,730 (10.31 MB)
#  Trainable params: 2,702,730 (10.31 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.2604 - loss: 1.9468 - val_accuracy: 0.4579 - val_loss: 1.5091
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4542 - loss: 1.4912 - val_accuracy: 0.5385 - val_loss: 1.2800
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5134 - loss: 1.3415 - val_accuracy: 0.5690 - val_loss: 1.2218
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5567 - loss: 1.2438 - val_accuracy: 0.6023 - val_loss: 1.1585
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5793 - loss: 1.1758 - val_accuracy: 0.6169 - val_loss: 1.0942
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6013 - loss: 1.1182 - val_accuracy: 0.6153 - val_loss: 1.0805
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6180 - loss: 1.0810 - val_accuracy: 0.6301 - val_loss: 1.0524
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6314 - loss: 1.0399 - val_accuracy: 0.6286 - val_loss: 1.0679
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6443 - loss: 1.0204 - val_accuracy: 0.6633 - val_loss: 0.9574
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6471 - loss: 0.9983 - val_accuracy: 0.6693 - val_loss: 0.9466
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6587 - loss: 0.9631 - val_accuracy: 0.6769 - val_loss: 0.9234
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6692 - loss: 0.9449 - val_accuracy: 0.6763 - val_loss: 0.9268
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6746 - loss: 0.9271 - val_accuracy: 0.6889 - val_loss: 0.9119
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6785 - loss: 0.9057 - val_accuracy: 0.6796 - val_loss: 0.9209
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6820 - loss: 0.9063 - val_accuracy: 0.6897 - val_loss: 0.9010
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6868 - loss: 0.8824 - val_accuracy: 0.7006 - val_loss: 0.8811
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6933 - loss: 0.8748 - val_accuracy: 0.6959 - val_loss: 0.8712
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6955 - loss: 0.8623 - val_accuracy: 0.7116 - val_loss: 0.8442
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7040 - loss: 0.8540 - val_accuracy: 0.7073 - val_loss: 0.8517
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7012 - loss: 0.8407 - val_accuracy: 0.7232 - val_loss: 0.8139
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7100 - loss: 0.8284 - val_accuracy: 0.7034 - val_loss: 0.8698
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7133 - loss: 0.8231 - val_accuracy: 0.6871 - val_loss: 0.9184
# Epoch 23/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7130 - loss: 0.8225 - val_accuracy: 0.7223 - val_loss: 0.8131
# Epoch 24/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7192 - loss: 0.7990 - val_accuracy: 0.7065 - val_loss: 0.8596
# Epoch 25/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7167 - loss: 0.8048 - val_accuracy: 0.7226 - val_loss: 0.8123
# Epoch 26/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7241 - loss: 0.7929 - val_accuracy: 0.7212 - val_loss: 0.8261
# Epoch 27/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7235 - loss: 0.7868 - val_accuracy: 0.7199 - val_loss: 0.8215
# Epoch 28/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7328 - loss: 0.7786 - val_accuracy: 0.7300 - val_loss: 0.7849
# Epoch 29/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7300 - loss: 0.7689 - val_accuracy: 0.7234 - val_loss: 0.8121
# Epoch 30/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7344 - loss: 0.7573 - val_accuracy: 0.7327 - val_loss: 0.7871
# Epoch 31/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7386 - loss: 0.7618 - val_accuracy: 0.7351 - val_loss: 0.8003
# Epoch 32/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7376 - loss: 0.7565 - val_accuracy: 0.7286 - val_loss: 0.8044
# Epoch 33/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7398 - loss: 0.7471 - val_accuracy: 0.7262 - val_loss: 0.8174
# Epoch 34/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7449 - loss: 0.7275 - val_accuracy: 0.7346 - val_loss: 0.7838
# Epoch 35/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7470 - loss: 0.7274 - val_accuracy: 0.7230 - val_loss: 0.8173
# Epoch 36/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7487 - loss: 0.7220 - val_accuracy: 0.7209 - val_loss: 0.8461
# Epoch 37/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7516 - loss: 0.7131 - val_accuracy: 0.7321 - val_loss: 0.8035
# Epoch 38/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7552 - loss: 0.7082 - val_accuracy: 0.7455 - val_loss: 0.7648
# Epoch 39/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7595 - loss: 0.7054 - val_accuracy: 0.7405 - val_loss: 0.7729
# Epoch 40/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7534 - loss: 0.7053 - val_accuracy: 0.7334 - val_loss: 0.8014
# Epoch 41/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7609 - loss: 0.7001 - val_accuracy: 0.7337 - val_loss: 0.7936
# Epoch 42/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7594 - loss: 0.6987 - val_accuracy: 0.7353 - val_loss: 0.7906
# Epoch 43/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7666 - loss: 0.6771 - val_accuracy: 0.7355 - val_loss: 0.7780
# Epoch 44/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7721 - loss: 0.6615 - val_accuracy: 0.7353 - val_loss: 0.7967
# Epoch 45/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7669 - loss: 0.6705 - val_accuracy: 0.7278 - val_loss: 0.8076
# Epoch 46/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7694 - loss: 0.6708 - val_accuracy: 0.7330 - val_loss: 0.7897
# Epoch 47/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7724 - loss: 0.6581 - val_accuracy: 0.7320 - val_loss: 0.7941
# Epoch 48/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7740 - loss: 0.6550 - val_accuracy: 0.7441 - val_loss: 0.7907
# Epoch 49/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7693 - loss: 0.6706 - val_accuracy: 0.7415 - val_loss: 0.8069
# Epoch 50/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7746 - loss: 0.6505 - val_accuracy: 0.7421 - val_loss: 0.7803
# Epoch 51/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7760 - loss: 0.6528 - val_accuracy: 0.7491 - val_loss: 0.7651
# Epoch 52/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7787 - loss: 0.6413 - val_accuracy: 0.7314 - val_loss: 0.8141
# Epoch 53/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7840 - loss: 0.6305 - val_accuracy: 0.7362 - val_loss: 0.7912
# Epoch 54/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7821 - loss: 0.6399 - val_accuracy: 0.7440 - val_loss: 0.7841
# Epoch 55/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7802 - loss: 0.6351 - val_accuracy: 0.7449 - val_loss: 0.7871
# Epoch 56/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7848 - loss: 0.6316 - val_accuracy: 0.7579 - val_loss: 0.7428
# Epoch 57/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7857 - loss: 0.6178 - val_accuracy: 0.7521 - val_loss: 0.7612
# Epoch 58/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7845 - loss: 0.6298 - val_accuracy: 0.7511 - val_loss: 0.7618
# Epoch 59/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7883 - loss: 0.6184 - val_accuracy: 0.7461 - val_loss: 0.7652
# Epoch 60/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7882 - loss: 0.6168 - val_accuracy: 0.7519 - val_loss: 0.7848
# Epoch 61/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7910 - loss: 0.6092 - val_accuracy: 0.7534 - val_loss: 0.7654
# Epoch 62/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7960 - loss: 0.5979 - val_accuracy: 0.7469 - val_loss: 0.7821
# Epoch 63/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7951 - loss: 0.5975 - val_accuracy: 0.7523 - val_loss: 0.7641
# Epoch 64/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7928 - loss: 0.6038 - val_accuracy: 0.7377 - val_loss: 0.7934
# Epoch 65/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7918 - loss: 0.6052 - val_accuracy: 0.7375 - val_loss: 0.7710
# Epoch 66/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7995 - loss: 0.5888 - val_accuracy: 0.7546 - val_loss: 0.7462
# Epoch 67/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7971 - loss: 0.5936 - val_accuracy: 0.7453 - val_loss: 0.8050
# Epoch 68/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7983 - loss: 0.5921 - val_accuracy: 0.7547 - val_loss: 0.7676
# Epoch 69/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8021 - loss: 0.5900 - val_accuracy: 0.7516 - val_loss: 0.7729
# Epoch 70/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8024 - loss: 0.5760 - val_accuracy: 0.7339 - val_loss: 0.8140
# Epoch 71/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7997 - loss: 0.5803 - val_accuracy: 0.7542 - val_loss: 0.7486
# Epoch 72/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8075 - loss: 0.5740 - val_accuracy: 0.7517 - val_loss: 0.7950
# Epoch 73/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8039 - loss: 0.5779 - val_accuracy: 0.7336 - val_loss: 0.8271
# Epoch 74/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8103 - loss: 0.5618 - val_accuracy: 0.7474 - val_loss: 0.7966
# Epoch 75/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8070 - loss: 0.5722 - val_accuracy: 0.7507 - val_loss: 0.7774
# Epoch 76/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8082 - loss: 0.5706 - val_accuracy: 0.7510 - val_loss: 0.7808
# Epoch 77/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8120 - loss: 0.5609 - val_accuracy: 0.7426 - val_loss: 0.8125
# Epoch 78/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8141 - loss: 0.5478 - val_accuracy: 0.7509 - val_loss: 0.7718
# Epoch 79/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8103 - loss: 0.5560 - val_accuracy: 0.6885 - val_loss: 0.9799
# Epoch 80/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8078 - loss: 0.5732 - val_accuracy: 0.7406 - val_loss: 0.8053
# Epoch 81/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8088 - loss: 0.5643 - val_accuracy: 0.7369 - val_loss: 0.8479
# Epoch 82/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8155 - loss: 0.5460 - val_accuracy: 0.7512 - val_loss: 0.7746
# Epoch 83/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8165 - loss: 0.5466 - val_accuracy: 0.7141 - val_loss: 0.9419
# Epoch 84/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8079 - loss: 0.5634 - val_accuracy: 0.7562 - val_loss: 0.7543
# Epoch 85/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8229 - loss: 0.5225 - val_accuracy: 0.7534 - val_loss: 0.8029
# Epoch 86/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8151 - loss: 0.5508 - val_accuracy: 0.7404 - val_loss: 0.8282
# Epoch 87/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8164 - loss: 0.5486 - val_accuracy: 0.7470 - val_loss: 0.8084
# Epoch 88/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8195 - loss: 0.5303 - val_accuracy: 0.7486 - val_loss: 0.8197
# Epoch 89/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8211 - loss: 0.5296 - val_accuracy: 0.7352 - val_loss: 0.8179
# Epoch 90/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8167 - loss: 0.5424 - val_accuracy: 0.7368 - val_loss: 0.8709
# Epoch 91/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8228 - loss: 0.5283 - val_accuracy: 0.7460 - val_loss: 0.8060
# Epoch 92/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8222 - loss: 0.5281 - val_accuracy: 0.7488 - val_loss: 0.7986
# Epoch 93/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8210 - loss: 0.5434 - val_accuracy: 0.7290 - val_loss: 0.8423
# Epoch 94/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8221 - loss: 0.5316 - val_accuracy: 0.7499 - val_loss: 0.8147
# Epoch 95/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8208 - loss: 0.5285 - val_accuracy: 0.7434 - val_loss: 0.8102
# Epoch 96/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8266 - loss: 0.5232 - val_accuracy: 0.7420 - val_loss: 0.8269
# Epoch 97/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8260 - loss: 0.5184 - val_accuracy: 0.7424 - val_loss: 0.8152
# Epoch 98/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8276 - loss: 0.5112 - val_accuracy: 0.7399 - val_loss: 0.8134
# Epoch 99/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8308 - loss: 0.5041 - val_accuracy: 0.7479 - val_loss: 0.8472
# Epoch 100/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8307 - loss: 0.5089 - val_accuracy: 0.7439 - val_loss: 0.8427

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_2, to_file='cnn_plot.png', show_shapes=True, show_layer_names=True)

# %%
visualkeras.layered_view(model_2, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=653x193>

# %%
evaluation = model_2.evaluate(X_test, Y_test_en)
print('Test Accuracy of Model_2(with more  filters): {}'.format(evaluation[1]))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7470 - loss: 0.8414
# Test Accuracy of Model_2(with more  filters): 0.7439000010490417

# %%
def plotloss(history_2):
    plt.plot(history_2.history['loss'])
    plt.plot(history_2.history['val_loss'])
    plt.plot(history_2.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()
plotloss(history_2)

# %% [markdown]
#  After running our model_2 with 100 Epochs, we can see that the validation accuracy has further improved to 74%
# <br><br>
# We will continue to train our model by adding Batch Normalization.

# %% [markdown]
# ## Model-3 with Batch Normalization

# %%
# Model_3 with Batch Normalization
model_3 = Sequential()
model_3.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(MaxPooling2D(pool_size=(2,2)))
model_3.add(Dropout(0.2))
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(MaxPooling2D(pool_size=(2,2)))
model_3.add(Dropout(0.25))
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model_3.add(BatchNormalization())
model_3.add(MaxPooling2D(pool_size=(2,2)))
model_3.add(Dropout(0.35))
model_3.add(Flatten())
model_3.add(Dense(256, activation='relu'))
model_3.add(BatchNormalization())
model_3.add(Dropout(0.5))
model_3.add(Dense(10, activation='softmax'))
model_3.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_3.summary()
history_3 = model_3.fit(X_train, Y_train_en, epochs = 100, verbose = 1, validation_data = (X_test, Y_test_en))
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 32, 32, 64)          │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 32, 32, 64)          │          65,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 16, 16, 128)         │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 16, 16, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 8, 8, 128)           │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 8, 8, 128)           │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,517,450 (5.79 MB)
#  Trainable params: 1,515,658 (5.78 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.3660 - loss: 1.9655 - val_accuracy: 0.5516 - val_loss: 1.2327
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6568 - loss: 0.9772 - val_accuracy: 0.6383 - val_loss: 1.0792
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.7328 - loss: 0.7693 - val_accuracy: 0.7167 - val_loss: 0.7817
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.7834 - loss: 0.6374 - val_accuracy: 0.7937 - val_loss: 0.6099
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8194 - loss: 0.5334 - val_accuracy: 0.7956 - val_loss: 0.6108
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8413 - loss: 0.4730 - val_accuracy: 0.8265 - val_loss: 0.5147
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8589 - loss: 0.4124 - val_accuracy: 0.8328 - val_loss: 0.4971
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8781 - loss: 0.3608 - val_accuracy: 0.8152 - val_loss: 0.5632
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8924 - loss: 0.3163 - val_accuracy: 0.8317 - val_loss: 0.5276
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9054 - loss: 0.2751 - val_accuracy: 0.8369 - val_loss: 0.5258
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9108 - loss: 0.2616 - val_accuracy: 0.8292 - val_loss: 0.5500
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9170 - loss: 0.2395 - val_accuracy: 0.8521 - val_loss: 0.4935
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9284 - loss: 0.2051 - val_accuracy: 0.8608 - val_loss: 0.4706
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9346 - loss: 0.1923 - val_accuracy: 0.8392 - val_loss: 0.5714
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9384 - loss: 0.1774 - val_accuracy: 0.8584 - val_loss: 0.4894
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9418 - loss: 0.1651 - val_accuracy: 0.8518 - val_loss: 0.5032
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9452 - loss: 0.1612 - val_accuracy: 0.8636 - val_loss: 0.4978
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9509 - loss: 0.1396 - val_accuracy: 0.8584 - val_loss: 0.5221
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9523 - loss: 0.1423 - val_accuracy: 0.8653 - val_loss: 0.5137
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9538 - loss: 0.1315 - val_accuracy: 0.8553 - val_loss: 0.5580
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9558 - loss: 0.1272 - val_accuracy: 0.8640 - val_loss: 0.5460
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9576 - loss: 0.1234 - val_accuracy: 0.8629 - val_loss: 0.5538
# Epoch 23/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9615 - loss: 0.1100 - val_accuracy: 0.8594 - val_loss: 0.5241
# Epoch 24/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9645 - loss: 0.1033 - val_accuracy: 0.8626 - val_loss: 0.5527
# Epoch 25/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9641 - loss: 0.1071 - val_accuracy: 0.8591 - val_loss: 0.5552
# Epoch 26/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9635 - loss: 0.1042 - val_accuracy: 0.8663 - val_loss: 0.5253
# Epoch 27/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9667 - loss: 0.0962 - val_accuracy: 0.8587 - val_loss: 0.5649
# Epoch 28/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9675 - loss: 0.0951 - val_accuracy: 0.8653 - val_loss: 0.5522
# Epoch 29/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9673 - loss: 0.0953 - val_accuracy: 0.8608 - val_loss: 0.5508
# Epoch 30/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9673 - loss: 0.0934 - val_accuracy: 0.8643 - val_loss: 0.5658
# Epoch 31/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9694 - loss: 0.0911 - val_accuracy: 0.8725 - val_loss: 0.5329
# Epoch 32/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9722 - loss: 0.0816 - val_accuracy: 0.8654 - val_loss: 0.5785
# Epoch 33/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9714 - loss: 0.0844 - val_accuracy: 0.8672 - val_loss: 0.5803
# Epoch 34/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9733 - loss: 0.0776 - val_accuracy: 0.8656 - val_loss: 0.5553
# Epoch 35/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9733 - loss: 0.0797 - val_accuracy: 0.8654 - val_loss: 0.5988
# Epoch 36/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9739 - loss: 0.0750 - val_accuracy: 0.8728 - val_loss: 0.5375
# Epoch 37/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9755 - loss: 0.0711 - val_accuracy: 0.8683 - val_loss: 0.5675
# Epoch 38/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9745 - loss: 0.0731 - val_accuracy: 0.8557 - val_loss: 0.6079
# Epoch 39/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9770 - loss: 0.0675 - val_accuracy: 0.8713 - val_loss: 0.5645
# Epoch 40/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9772 - loss: 0.0671 - val_accuracy: 0.8680 - val_loss: 0.5650
# Epoch 41/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9795 - loss: 0.0643 - val_accuracy: 0.8717 - val_loss: 0.5651
# Epoch 42/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9771 - loss: 0.0670 - val_accuracy: 0.8710 - val_loss: 0.5904
# Epoch 43/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9776 - loss: 0.0635 - val_accuracy: 0.8657 - val_loss: 0.6260
# Epoch 44/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9806 - loss: 0.0606 - val_accuracy: 0.8703 - val_loss: 0.5944
# Epoch 45/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9775 - loss: 0.0635 - val_accuracy: 0.8724 - val_loss: 0.5766
# Epoch 46/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9806 - loss: 0.0595 - val_accuracy: 0.8753 - val_loss: 0.5742
# Epoch 47/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9809 - loss: 0.0584 - val_accuracy: 0.8651 - val_loss: 0.6350
# Epoch 48/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9798 - loss: 0.0616 - val_accuracy: 0.8667 - val_loss: 0.5972
# Epoch 49/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9797 - loss: 0.0572 - val_accuracy: 0.8656 - val_loss: 0.6121
# Epoch 50/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9796 - loss: 0.0589 - val_accuracy: 0.8690 - val_loss: 0.5992
# Epoch 51/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9815 - loss: 0.0567 - val_accuracy: 0.8714 - val_loss: 0.5758
# Epoch 52/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9802 - loss: 0.0581 - val_accuracy: 0.8706 - val_loss: 0.5936
# Epoch 53/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9816 - loss: 0.0545 - val_accuracy: 0.8631 - val_loss: 0.6386
# Epoch 54/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9824 - loss: 0.0507 - val_accuracy: 0.8734 - val_loss: 0.5914
# Epoch 55/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9834 - loss: 0.0508 - val_accuracy: 0.8673 - val_loss: 0.6195
# Epoch 56/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9828 - loss: 0.0515 - val_accuracy: 0.8733 - val_loss: 0.5932
# Epoch 57/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9826 - loss: 0.0530 - val_accuracy: 0.8766 - val_loss: 0.5926
# Epoch 58/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9834 - loss: 0.0481 - val_accuracy: 0.8728 - val_loss: 0.5769
# Epoch 59/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9837 - loss: 0.0483 - val_accuracy: 0.8731 - val_loss: 0.5957
# Epoch 60/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9829 - loss: 0.0488 - val_accuracy: 0.8690 - val_loss: 0.6085
# Epoch 61/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9843 - loss: 0.0475 - val_accuracy: 0.8692 - val_loss: 0.6073
# Epoch 62/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9847 - loss: 0.0453 - val_accuracy: 0.8734 - val_loss: 0.6057
# Epoch 63/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9827 - loss: 0.0512 - val_accuracy: 0.8766 - val_loss: 0.5840
# Epoch 64/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9862 - loss: 0.0394 - val_accuracy: 0.8741 - val_loss: 0.5964
# Epoch 65/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9848 - loss: 0.0476 - val_accuracy: 0.8718 - val_loss: 0.6271
# Epoch 66/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9849 - loss: 0.0442 - val_accuracy: 0.8727 - val_loss: 0.6262
# Epoch 67/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9838 - loss: 0.0466 - val_accuracy: 0.8646 - val_loss: 0.6766
# Epoch 68/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9854 - loss: 0.0410 - val_accuracy: 0.8701 - val_loss: 0.6306
# Epoch 69/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9850 - loss: 0.0415 - val_accuracy: 0.8691 - val_loss: 0.6420
# Epoch 70/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9860 - loss: 0.0425 - val_accuracy: 0.8691 - val_loss: 0.6386
# Epoch 71/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9868 - loss: 0.0377 - val_accuracy: 0.8733 - val_loss: 0.6371
# Epoch 72/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9855 - loss: 0.0445 - val_accuracy: 0.8749 - val_loss: 0.6109
# Epoch 73/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9860 - loss: 0.0426 - val_accuracy: 0.8766 - val_loss: 0.6079
# Epoch 74/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9874 - loss: 0.0375 - val_accuracy: 0.8730 - val_loss: 0.6418
# Epoch 75/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9866 - loss: 0.0405 - val_accuracy: 0.8693 - val_loss: 0.6380
# Epoch 76/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9873 - loss: 0.0397 - val_accuracy: 0.8772 - val_loss: 0.6109
# Epoch 77/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9867 - loss: 0.0388 - val_accuracy: 0.8732 - val_loss: 0.6190
# Epoch 78/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9887 - loss: 0.0325 - val_accuracy: 0.8677 - val_loss: 0.6509
# Epoch 79/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9858 - loss: 0.0383 - val_accuracy: 0.8833 - val_loss: 0.5991
# Epoch 80/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9876 - loss: 0.0361 - val_accuracy: 0.8735 - val_loss: 0.6254
# Epoch 81/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9885 - loss: 0.0324 - val_accuracy: 0.8701 - val_loss: 0.6887
# Epoch 82/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9878 - loss: 0.0353 - val_accuracy: 0.8758 - val_loss: 0.6304
# Epoch 83/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9886 - loss: 0.0347 - val_accuracy: 0.8757 - val_loss: 0.6184
# Epoch 84/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9884 - loss: 0.0340 - val_accuracy: 0.8706 - val_loss: 0.6629
# Epoch 85/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9877 - loss: 0.0364 - val_accuracy: 0.8815 - val_loss: 0.5993
# Epoch 86/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9876 - loss: 0.0367 - val_accuracy: 0.8804 - val_loss: 0.6221
# Epoch 87/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9887 - loss: 0.0348 - val_accuracy: 0.8793 - val_loss: 0.6290
# Epoch 88/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9871 - loss: 0.0376 - val_accuracy: 0.8769 - val_loss: 0.6263
# Epoch 89/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9885 - loss: 0.0340 - val_accuracy: 0.8771 - val_loss: 0.6366
# Epoch 90/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9858 - loss: 0.0414 - val_accuracy: 0.8735 - val_loss: 0.6329
# Epoch 91/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9889 - loss: 0.0344 - val_accuracy: 0.8797 - val_loss: 0.6336
# Epoch 92/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9887 - loss: 0.0346 - val_accuracy: 0.8782 - val_loss: 0.6295
# Epoch 93/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9893 - loss: 0.0352 - val_accuracy: 0.8791 - val_loss: 0.6033
# Epoch 94/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9874 - loss: 0.0357 - val_accuracy: 0.8733 - val_loss: 0.6483
# Epoch 95/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9892 - loss: 0.0325 - val_accuracy: 0.8749 - val_loss: 0.6464
# Epoch 96/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9894 - loss: 0.0307 - val_accuracy: 0.8807 - val_loss: 0.6284
# Epoch 97/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9892 - loss: 0.0317 - val_accuracy: 0.8779 - val_loss: 0.6071
# Epoch 98/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9891 - loss: 0.0313 - val_accuracy: 0.8788 - val_loss: 0.6479
# Epoch 99/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9908 - loss: 0.0281 - val_accuracy: 0.8701 - val_loss: 0.6788
# Epoch 100/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9878 - loss: 0.0346 - val_accuracy: 0.8793 - val_loss: 0.6082

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_3, to_file='cnn_plot.png', show_shapes=True, show_layer_names=True)

# %%
visualkeras.layered_view(model_3, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=927x209>

# %%
evaluation = model_3.evaluate(X_test, Y_test_en)
print('Test Accuracy of Model_3 (with Batch Normalization): {}'.format(evaluation[1]))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8821 - loss: 0.6011
# Test Accuracy of Model_3 (with Batch Normalization): 0.8792999982833862

# %%
def plotloss(history_3):
    plt.plot(history_3.history['loss'])
    plt.plot(history_3.history['val_loss'])
    plt.plot(history_3.history['accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation', 'Accuracy'])
    plt.show()
plotloss(history_3)

# %% [markdown]
#  After running our model_3 with Batch Normalization, we can see that the validation accuracy has further improved to 87%

# %% [markdown]
# ## Using VGG16
#
# What is VGG16?
#
# * VGG16 is a deep CNN architecture with 16 weight layers (13 convolutional + 3 fully connected), known for using only small 3×3 filters and 2×2 max pooling layers in a very consistent and simple structure.
#
# * It processes 224×224×3 input images, increasing filter depth progressively (64 → 512), while reducing spatial resolution through pooling, and ends with fully connected layers and a softmax classifier over 1000 classes.
#
# * Trained on the large-scale ImageNet dataset, VGG16 achieved ~71% top-1 and ~89% top-5 accuracy, and it's widely used in practice for transfer learning due to its solid performance and generalizability.
#
# * Compared to basic CNNs, VGG16 is much deeper, uses more filters per layer, and follows a strictly uniform design (all 3×3 convs), while basic CNNs often mix filter sizes and stay shallow.
#
# * VGG16 has ~138 million parameters, making it heavier but also more expressive than a standard CNN; its pretrained version is often reused in various computer vision tasks for fine-tuning.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
num_epochs = 5
batch_size = 40
learning_rate = 0.001
classes = ('plane', 'car' , 'bird',
    'cat', 'deer', 'dog',
    'frog', 'horse', 'ship', 'truck')
# Out:
# cuda

# %%
transform = transforms.Compose([
    transforms.Resize(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
       (0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)
    )
])
train_dataset = torchvision.datasets.CIFAR10(
    root= './data', train = True,
    download =True, transform = transform)
test_dataset = torchvision.datasets.CIFAR10(
    root= './data', train = False,
    download =True, transform = transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:05<00:00, 29.5MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
train_loader = torch.utils.data.DataLoader(train_dataset
    , batch_size = batch_size
    , shuffle = True)
test_loader = torch.utils.data.DataLoader(test_dataset
    , batch_size = batch_size
    , shuffle = True)
n_total_step = len(train_loader)
print(n_total_step)
# Out:
# 1250

# %%
model = models.vgg16(pretrained = True)
input_lastLayer = model.classifier[6].in_features
model.classifier[6] = nn.Linear(input_lastLayer,10)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate, momentum=0.9,weight_decay=5e-4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 234MB/s]

# %%
for epoch in range(num_epochs):
    for i, (imgs , labels) in enumerate(train_loader):
        imgs = imgs.to(device)
        labels = labels.to(device)

        labels_hat = model(imgs)
        n_corrects = (labels_hat.argmax(axis=1)==labels).sum().item()
        loss_value = criterion(labels_hat, labels)
        loss_value.backward()
        optimizer.step()
        optimizer.zero_grad()
        if (i+1) % 250 == 0:
           print(f'epoch {epoch+1}/{num_epochs}, step: {i+1}/{n_total_step}: loss = {loss_value:.5f}, acc = {100*(n_corrects/labels.size(0)):.2f}%')
    print()
# Out:
# epoch 1/5, step: 250/1250: loss = 0.34279, acc = 85.00%
# epoch 1/5, step: 500/1250: loss = 0.66696, acc = 80.00%
# epoch 1/5, step: 750/1250: loss = 0.55934, acc = 87.50%
# epoch 1/5, step: 1000/1250: loss = 0.27092, acc = 87.50%
# epoch 1/5, step: 1250/1250: loss = 0.26798, acc = 90.00%
#
# epoch 2/5, step: 250/1250: loss = 0.12615, acc = 97.50%
# epoch 2/5, step: 500/1250: loss = 0.06035, acc = 100.00%
# epoch 2/5, step: 750/1250: loss = 0.30092, acc = 82.50%
# epoch 2/5, step: 1000/1250: loss = 0.34073, acc = 90.00%
# epoch 2/5, step: 1250/1250: loss = 0.05454, acc = 100.00%
#
# epoch 3/5, step: 250/1250: loss = 0.04015, acc = 100.00%
# epoch 3/5, step: 500/1250: loss = 0.28035, acc = 87.50%
# epoch 3/5, step: 750/1250: loss = 0.22216, acc = 92.50%
# epoch 3/5, step: 1000/1250: loss = 0.24949, acc = 97.50%
# epoch 3/5, step: 1250/1250: loss = 0.05266, acc = 100.00%
#
# epoch 4/5, step: 250/1250: loss = 0.09575, acc = 95.00%
# epoch 4/5, step: 500/1250: loss = 0.08334, acc = 97.50%
# epoch 4/5, step: 750/1250: loss = 0.20640, acc = 92.50%
# epoch 4/5, step: 1000/1250: loss = 0.16638, acc = 95.00%
# epoch 4/5, step: 1250/1250: loss = 0.05351, acc = 100.00%
#
# epoch 5/5, step: 250/1250: loss = 0.03608, acc = 97.50%
# epoch 5/5, step: 500/1250: loss = 0.04199, acc = 97.50%
# epoch 5/5, step: 750/1250: loss = 0.03383, acc = 100.00%
# epoch 5/5, step: 1000/1250: loss = 0.09650, acc = 97.50%
# epoch 5/5, step: 1250/1250: loss = 0.01966, acc = 100.00%

# %%
torch.save(model,"vggmodel")

# %%
with torch.no_grad():
    number_corrects = 0
    number_samples = 0
    for i, (test_images_set , test_labels_set) in enumerate(test_loader):
        test_images_set = test_images_set.to(device)
        test_labels_set = test_labels_set.to(device)

        y_predicted = model(test_images_set)
        labels_predicted = y_predicted.argmax(axis = 1)
        number_corrects += (labels_predicted==test_labels_set).sum().item()
        number_samples += test_labels_set.size(0)
    print(f"Overall accuracy {(number_corrects / number_samples)*100}%")
# Out:
# Overall accuracy 91.89%

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

heatmap = pd.DataFrame(data=0, index=classes, columns=classes)

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        for i in range(images.size(0)):
            true_label = labels[i].item()
            predicted_label = predicted[i].item()
            heatmap.iloc[true_label, predicted_label] += 1

_, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(heatmap, annot=True, fmt="d", cmap="YlGnBu", ax=ax)
plt.show()

# %% [markdown]
# We see that a pretrained VGG16 when trained further on CIFAR-10 dataset, performs very well. It is probably difficult for Quantum Networks to achieve such accuracy but it is vital to test whether quantum concepts can provide major advantages to image classification by using their properties like superpositioning and entanglement.
#
#
# ## Final Results
#
# CNN (best model)- 88%
# VGG16- 91% Accuracy
